# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import time
from openpyxl import load_workbook
import os
import xlwings
import xlsxwriter

# %%
stock_list=['ASHOKA', 'BORORENEW', 'IRB', 'JSWENERGY', 'NBCC', 'GSFC', 'GMDCLTD', 'LANDMARK', 'SEQUENT',
 'PATANJALI', 'NAM-INDIA', 'NYKAA', 'EASEMYTRIP', 'JTEKTINDIA', 'JCHAC', 'SUPRAJIT', 'LATENTVIEW',
 'ICIL', 'ISGEC', 'ALOKINDS', 'SIEMENS', 'PRICOLLTD', 'ACLGATI', 'DLF', 'CAPLIPOINT', 'BAYERCROP',
 'DIVGIITTS', 'SURYAROSNI', 'POONAWALLA', 'MOTILALOFS', 'AHLUCONT', 'NATIONALUM', 'DCAL', 'COCHINSHIP',
 'MFSL', 'GODREJPROP', 'ABB', 'JTLIND', 'CHOICEIN', 'AVALON', 'GNFC', 'MINDACORP', 'TI', 'THOMASCOOK',
 'NFL', 'SCI', 'JINDALSAW', 'GREENPLY', 'SSWL', 'APOLLOTYRE', 'MSTCLTD', 'SOLARINDS', 'OBEROIRLTY',
 'HEROMOTOCO', 'TIPSINDLTD', 'ETHOSLTD', 'CARERATING', 'ADANIPORTS', 'BLS', 'CHALET', 'AMBER',
 'KAYNES', 'FINOPB', 'RCF', 'MANKIND', 'KALYANKJIL', 'INFIBEAM', 'MAPMYINDIA', 'CESC', 'SUNTECK',
 'PCBL', 'PHOENIXLTD', 'LLOYDSENGG', 'BALKRISIND', 'CENTURYTEX', 'TRENT', 'STAR', 'ABBOTINDIA',
 'ACCELYA', 'GRINFRA', 'GRANULES', 'MHRIL', 'HINDPETRO', 'SBILIFE', 'UTIAMC', 'EPIGRAL', 'STYLAMIND',
 'KIRLOSBROS', 'HEMIPROP', 'INDIGO', 'UJJIVAN', 'GET&D', 'ROLEXRINGS', 'INTELLECT', 'VBL', 'MANINFRA',
 'APOLLOHOSP', 'TRIDENT', 'ADANIENT', 'BRIGADE', 'LEMONTREE', 'BLUESTARCO', 'AEGISCHEM', 'PARADEEP',
 'MAXHEALTH', 'ECLERX', 'APOLLOPIPE', 'HCC', 'ARVIND', 'BIRLACORPN', 'WONDERLA', 'ADANIENSOL', 'GPIL',
 'LTTS', 'JSL', 'CEATLTD', 'GANESHHOUC', 'PRUDENT', 'BCG', 'VTL', 'GLS', 'MAYURUNIQ', 'BAJAJ-AUTO',
 'SUZLON', 'RVNL', 'DBREALTY', 'OLECTRA', 'KTKBANK', 'PETRONET', 'LT', 'WOCKPHARMA', 'APLAPOLLO',
 'EIHOTEL', 'HDFCAMC', 'JINDALSTEL', 'CONCOR', 'POLICYBZR', 'TATAMTRDVR', 'CENTURYPLY', 'MOLDTKPAC',
 'AARTIDRUGS', 'BOSCHLTD', 'EQUITASBNK', 'DBL', 'CIPLA', 'SCHAEFFLER', 'TDPOWERSYS', 'BHARATFORG',
 'TATAMOTORS', 'IPCALAB', 'SUNPHARMA', 'CHEMPLASTS', 'PSPPROJECT', 'NAUKRI', 'HCLTECH', 'BHARTIARTL',
 'ITI', 'NEOGEN', 'FSL', 'TINPLATE', 'GLENMARK', 'INDHOTEL', 'TATASTEEL', 'BEPL', 'RAINBOW',
 'LAURUSLABS', 'DCXINDIA', 'CUMMINSIND', 'BSOFT', 'MARICO', 'FIVESTAR', 'ELECON', 'LTIM', 'LICI',
 'COALINDIA', 'IEX', 'JUBLPHARMA', 'BDL', 'DIVISLAB', 'JKIL', 'SHYAMMETL', 'DOLLAR', 'EIDPARRY',
 'BERGEPAINT', 'HEIDELBERG', 'MOTHERSON', 'TITAGARH', 'QUESS', 'PRESTIGE', 'CONCORDBIO', 'VSTTILLERS',
 'HONAUT', 'CIEINDIA', 'SOMANYCERA', 'NH', 'TTKPRESTIG', 'AUTOAXLES', 'GUJGASLTD', 'GODFRYPHLP',
 'RADICO', 'BSE', 'VIJAYA', 'GHCL', 'GALAXYSURF', 'EXIDEIND', 'FUSION', 'GRINDWELL', 'FIEMIND',
 'JKPAPER', 'KIMS', 'JISLJALEQS', 'LUPIN', 'BALRAMCHIN', 'RUPA', 'SUVENPHAR', 'POWERINDIA', 'NMDC',
 'CREDITACC', 'CARBORUNIV', 'IGL', 'RAJESHEXPO', 'LAOPALA', 'PIIND', 'NTPC', 'VOLTAMP', 'HUDCO', 'MOL',
 'SYNGENE', 'TATACOMM', 'BPCL', 'SONATSOFTW', 'JBCHEPHARM', 'NCC', 'CCL', 'M&M', 'MARUTI', 'JKTYRE',
 'KOLTEPATIL', 'PNCINFRA', 'DODLA', 'RAJRATAN', 'ASTRAL', 'EPL', 'JAICORPLTD', 'TIRUMALCHM', 'IRCON',
 'TEGA', 'KPITTECH', 'TECHM', 'PTC', 'JBMA', 'TORNTPHARM', 'BEL', 'GLAND', 'ZOMATO', 'SULA',
 'FINCABLES', 'INGERRAND', 'ANANDRATHI', 'SWSOLAR', 'POWERMECH', 'AARTIIND', 'SUNFLAG', 'RAMKY', 'HAL',
 'IIFL', 'INDIACEM', 'KPRMILL', 'RITES', 'ANANTRAJ', 'OIL', 'SHARDACROP', 'KFINTECH', 'ARVINDFASN',
 'HINDCOPPER', 'LUXIND', 'TRIVENI', 'FEDERALBNK', 'SUNDRMFAST', 'UNOMINDA', 'NRBBEARING', 'KIRLOSENG',
 'BBTC', 'PAISALO', 'HGS', 'FACT', 'TECHNOE', 'VEDL', 'PIDILITIND', 'MAZDOCK', 'ZFCVINDIA', 'TATACHEM',
 'TMB', 'TATAPOWER', 'BANDHANBNK', 'DEVYANI', 'TCS', 'INFY', 'TANLA', 'TIINDIA', '3MINDIA', 'LODHA',
 'DEEPAKNTR', 'WHIRLPOOL', 'RAILTEL', 'NESCO', 'TATAMETALI', 'BAJAJCON', 'WELSPUNLIV', 'MOIL',
 'J&KBANK', 'AUROPHARMA', 'TATAELXSI', 'SAKSOFT', 'DIXON', 'GSPL', 'HOMEFIRST', 'NATCOPHARM',
 'GMMPFAUDLR', 'HARSHA', 'RKFORGE', 'HERITGFOOD', 'CARYSIL', 'MSUMI', 'COSMOFIRST', 'FINEORG',
 'DMART', 'SHAREINDIA', 'JKCEMENT', 'GAIL', 'CHENNPETRO', 'HAPPSTMNDS', 'BHEL', 'AAVAS', 'ASTRAMICRO',
 'IFBIND', 'VRLLOG', 'GUJALKALI', 'TATACONSUM', 'STARCEMENT', 'VINATIORGA', 'IKIO', 'IRCTC', 'SYRMA',
 'GATEWAY', 'ASTERDM', 'ICICIGI', '360ONE', 'CROMPTON', 'SBCL', 'AWL', 'RATNAMANI', 'LGBBROSLTD', 
 'KKCL', 'HGINFRA', 'UJJIVANSFB', 'ISEC', 'WIPRO', 'BANKINDIA', 'CANFINHOME', 'JUBLINGREA',
 'AARTIPHARM', 'EMIL', 'ADANIGREEN', 'PERSISTENT', 'KAJARIACER', 'UFLEX', 'VOLTAS', 'HSCL', 'KRBL',
 'PGEL', 'JUSTDIAL', 'PRSMJOHNSN', 'SOUTHBANK', 'ZYDUSLIFE', 'GRAPHITE', 'GABRIEL', 'INDIAGLYCO',
 'UNIPARTS', 'SOBHA', 'COFORGE', 'CHOLAFIN', 'CHAMBLFERT', 'BIOCON', 'LICHSGFIN', 'OPTIEMUS',
 'JYOTHYLAB', 'CAMS', 'UNIONBANK', 'HAVELLS', 'WSTCSTPAPR', 'SPARC', 'MRPL', 'INDIGOPNTS', 
 'ITDCEM', 'CYIENT', 'KANSAINER', 'TIDEWATER', 'CGPOWER', 'MAHLOG', 'PGHL', 'HINDUNILVR', 
 'ROUTE', 'STARHEALTH', 'GREENLAM', 'PNBHOUSING', 'IRFC', 'VESUVIUS', 'BALMLAWRIE', 'SHOPERSTOP',
 'MASTEK', 'POWERGRID', 'AIAENG', 'ABCAPITAL', 'LINDEINDIA', 'CANBK', 'IBREALEST', 'JMFINANCIL',
 'CONFIPET', 'DWARKESH', 'EVEREADY', 'AETHER', 'SAREGAMA', 'SONACOMS', 'BAJAJHLDNG', 'ATGL', 
 'TORNTPOWER', 'SUPRIYA', 'AGI', 'RAYMOND', 'SAIL', 'BEML', 'HINDWAREAP', 'ELGIEQUIP', 'BANKBARODA',
 'NHPC', 'METROPOLIS', 'IDBI', 'ERIS', 'CDSL', 'KIRIINDUS', 'LXCHEM', 'RENUKA', 'GRASIM', 'MRF',
 'CERA', 'IOLCP', 'EDELWEISS', 'INDUSINDBK', 'JSWSTEEL', 'KOTAKBANK', 'SIYSIL', 'FDC', 'DALMIASUG', 
 'MCDOWELL-N', 'SBIN', 'PFIZER', 'RELAXO', 'ANGELONE', 'PPLPHARMA', 'BAJAJHIND', 'DRREDDY', 'CRISIL', 
 'APTUS', 'JAMNAAUTO', 'UNICHEMLAB', 'IOC', 'TITAN', 'GPPL', 'SUNTV', 'SPANDANA', 'YESBANK',
 'MANYAVAR', 'PNB', 'FINPIPE', 'ADANIPOWER', 'TATAINVEST', 'SCHNEIDER', 'ASTRAZEN', 'SYMPHONY', 
 'MARKSANS', 'USHAMART', 'UCOBANK', 'VENKEYS', 'SHREECEM', 'NAZARA', 'BAJFINANCE', 'RELIANCE', 
 'BECTORFOOD', 'KNRCON', 'ITC', 'NOCIL', 'AXISBANK', 'ICICIPRULI', 'SIS', 'ALKEM', 'THERMAX', 
 'ENGINERSIN', 'HNDFDS', 'GRSE', 'MAHABANK', 'SBFC', 'KSCL', 'SUMICHEM', 'PGHH', 'CHOLAHLDNG', 
 'ULTRACEMCO', 'EICHERMOT', 'SANOFI', 'HINDALCO', 'PAYTM', 'ADVENZYMES', 'SFL', 'PRIVISCL', 'ROSSARI',
 'PEL', 'APCOTEXIND', 'OFSS', 'ICICIBANK', 'MAITHANALL', 'M&MFIN', 'ASHOKLEY', 'SJVN', 'GRAVITA', 
 'TEAMLEASE', 'ZENTEC', 'THYROCARE', 'CASTROLIND', 'DATAMATICS', 'TIMETECHNO', 'RTNPOWER', 'HINDZINC',
 'IOB', 'TIIL', 'CAMLINFINE', 'MTARTECH', 'AMIORG', 'GICRE', 'NSLNISP', 'CUB', 'VARROC', 'MGL', 'KPIL',
 'BOMDYEING', 'NUVOCO', 'VMART', 'BARBEQUE', 'HLEGLAS', 'HBLPOWER', 'ONGC', 'DALBHARAT', 'TARSONS', 
 'UPL', 'SHILPAMED', 'GESHIP', 'KARURVYSYA', 'ACE', 'MAHSEAMLES', 'CMSINFO', 'HIL', 'RATEGAIN', 
 'DELTACORP', 'ATUL', 'SBICARD', 'SHANTIGEAR', 'STLTECH', 'PRINCEPIPE', 'FORTIS', 'CARTRADE', 'TTML',
 'DELHIVERY', 'GREENPANEL', 'ORIENTELEC', 'ALKYLAMINE', 'TEJASNET', 'TCIEXP', 'ABFRL', 'KEC', 
 'MEDPLUS', 'PARAS', 'GOCOLORS', 'LALPATHLAB', 'SKFINDIA', 'HDFCBANK', 'JINDALPOLY', 'GODREJAGRO', 
 'PRAJIND', 'LTFOODS', 'BLUEDART', 'VGUARD', 'ASIANPAINT', 'TVSSCS', 'AFFLE', 'NIACL', 'HCG', 'RHIM',
 'KIRLPNU', 'REDINGTON', 'JINDWORLD', 'INDIANB', 'CAMPUS', 'FCL', 'TVSMOTOR', 'APLLTD', 'GUFICBIO', 
 'IDFC', 'CENTRALBK', 'SWANENERGY', 'VIPIND', 'HDFCLIFE', 'DBCORP', 'GREAVESCOT', 'NESTLEIND', 
 'GLOBUSSPR', 'DATAPATTNS', 'WESTLIFE', 'TIMKEN', 'SAFARI', 'BAJAJFINSV', 'SUBEXLTD', 'TCI',
 'DREAMFOLKS', 'ASTEC', 'TCNSBRANDS', 'SPLPETRO', 'DABUR', 'RAMCOCEM', 'POLYMED', 'CIGNITITEC',
 'AVANTIFEED', 'NETWORK18', 'SUDARSCHEM', 'AMBUJACEM', 'KRSNAA', 'ORIENTCEM', 'MPHASIS', 'DEN', 
 'BIKAJI', 'L&TFH', 'IMFA', 'SHRIRAMFIN', 'EMAMILTD', 'DCMSHRIRAM', 'NEWGEN', 'BATAINDIA', 'ESABINDIA',
 'CRAFTSMAN', 'MIDHANI', 'MUTHOOTFIN', 'PVRINOX', 'MEDANTA', 'ARE&M', 'LAXMIMACH', 'MAHLIFE',
 'BRITANNIA', 'MASFIN', 'GLAXO', 'MANAPPURAM', 'IONEXCHANG', 'WABAG', 'SAPPHIRE', 'NEULANDLAB',
 'MMTC', 'ESCORTS', 'RBLBANK', 'NAVNETEDUL', 'GODREJCP', 'IDFCFIRSTB', 'HIKAL', 'RAIN', 'NLCINDIA', 
 'EMUDHRA', 'INDUSTOWER', 'HEG', 'ASAHIINDIA', 'CLEAN', 'PTCIL', 'AJANTPHARM', 'RELINFRA', 'IFCI',
 'STYRENIX', 'RBA', 'SUPREMEIND', 'WELENT', 'ENDURANCE', 'RELIGARE', 'HFCL', 'TRITURBINE', 'BALAMINES',
 'SANSERA', 'RECLTD', 'ACI', 'ZYDUSWELL', 'INDOCO', 'GAEL', 'POLYPLEX', 'DEEPAKFERT', 'RPOWER', 'JWL',
 'SUNDARMFIN', 'ZENSARTECH', 'NAVA', 'JUBLFOOD', 'RALLIS', 'KSB', 'GOKEX', 'DCBBANK', 'ACC', 
 'RESPONIND', 'SARDAEN', 'PDSL', 'GMRINFRA', 'HINDOILEXP', 'COLPAL', 'COROMANDEL', 'VAIBHAVGBL',
 'MCX', 'APARINDS', 'TV18BRDCST', 'INDIAMART', 'UBL', 'FLUOROCHEM', 'DHANI', 'TATVA', 'JKLAKSHMI',
 'METROBRAND', 'KEI', 'HATHWAY', 'CSBBANK', 'NAVINFLUOR', 'AUBANK', 'PAGEIND', 'PFC', 'JPPOWER', 
 'ANURAS', 'IBULHSGFIN', 'SRF', 'INOXWIND', 'ELECTCAST', 'RTNINDIA', 'WELCORP', 'GILLETTE',
 'GODREJIND', 'CGCL', 'GARFIBRES',
 'DISHTV', 'IDEA', 'JPASSOCIAT', 'ALLCARGO', 'ZEEL', 'POLYCAB']

# %%
for stock in stock_list:
    url = 'https://www.screener.in/company/'+stock
    print(url)
# Out:
# https://www.screener.in/company/ASHOKA
# https://www.screener.in/company/BORORENEW
# https://www.screener.in/company/IRB
# https://www.screener.in/company/JSWENERGY
# https://www.screener.in/company/NBCC
# https://www.screener.in/company/GSFC
# https://www.screener.in/company/GMDCLTD
# https://www.screener.in/company/LANDMARK
# https://www.screener.in/company/SEQUENT
# https://www.screener.in/company/PATANJALI
# https://www.screener.in/company/NAM-INDIA
# https://www.screener.in/company/NYKAA
# https://www.screener.in/company/EASEMYTRIP
# https://www.screener.in/company/JTEKTINDIA
# https://www.screener.in/company/JCHAC
# https://www.screener.in/company/SUPRAJIT
# https://www.screener.in/company/LATENTVIEW
# https://www.screener.in/company/ICIL
# https://www.screener.in/company/ISGEC
# https://www.screener.in/company/ALOKINDS
# https://www.screener.in/company/SIEMENS
# https://www.screener.in/company/PRICOLLTD
# https://www.screener.in/company/ACLGATI
# ...

# %% [markdown]
# https://www.screener.in/company/compare/00000006/?limit=50&page=1

# %%
stock_list=['PNB','BANKBARODA','AXISBANK','ICICIBANK','SBIN','IOB',
'INDUSINDBK','UNIONBANK','CANBK','KOTAKBANK','IDBI']


directory= 'C:\\Users\\User\OneDrive\\Documents\\screener_data\\'

# %%
import os
import time
import pandas as pd

stock_list=['PNB','BANKBARODA','AXISBANK','ICICIBANK','SBIN','IOB',
'INDUSINDBK','UNIONBANK','CANBK','KOTAKBANK','IDBI']

# Create a new DataFrame to store all the data
balance = pd.DataFrame()
p_l = pd.DataFrame()
cash = pd.DataFrame()
# Create a new Excel workbook
writer = pd.ExcelWriter('C:\\Users\\User\\OneDrive\\Documents\\screener_data\\combined_data.xlsx')

for stock in stock_list:
    url = 'https://www.screener.in/company/'+stock
    table=pd.read_html(url)

    balance_sheet=table[6]
    profit_loss=table[1]
    cash_flow=table[7]
    time.sleep(5)

    # Add a column to identify the data of different companies
    balance_sheet['Company'] = stock
    balance_sheet['Sheet'] = 'Balance Sheet'
    profit_loss['Company'] = stock
    profit_loss['Sheet'] = 'Profit and Loss Statement'
    cash_flow['Company'] = stock
    cash_flow['Sheet'] = 'Cash Flow Statement'
    
    
    # Append the data of each company to the combined DataFrame
    balance = balance.append(balance_sheet, ignore_index=True)
    p_l = p_l.append(profit_loss, ignore_index=True)
    cash = cash.append(cash_flow, ignore_index=True)
    
    balance.to_excel(writer, sheet_name='Balance_Sheet')
    p_l.to_excel(writer, sheet_name='Profit_Loss_Statement')
    cash.to_excel(writer, sheet_name='Cash_Flow_Statement')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16600\1712383517.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   balance = balance.append(balance_sheet, ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_16600\1712383517.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p_l = p_l.append(profit_loss, ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_16600\1712383517.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cash = cash.append(cash_flow, ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_16600\1712383517.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
url = "https://www.screener.in/company/HDFCBANK/consolidated/"
    
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36',
        'Accept-Language':'en-US'
    }    

    
    
response = requests.get(url,headers= headers)
soup = BeautifulSoup(response.text,'lxml')
table= soup.find('table', class_="data-table responsive-text-nowrap")
head= table.find_all("th")
body= table.find_all("tr")



column=[]
for i in head:
    title=i.text
    column.append(title)
df=pd.DataFrame(columns=column)
for i in body[1:]:
    data=i.find_all("td")
    r=[tr.text for tr in data]
    df.loc[len(df)]=r

df
# Out:
#                                                        Dec 2020  Mar 2021  \
# 0   \n            \n              Revenue\n       ...    31,852    32,607
# 1   \n            \n              Interest\n      ...    14,523    14,083
# 2                  \n\n                Expenses +\n\n    13,503    15,561
# 3   \n            \n              Financing Profit...     3,826     2,963
# 4   \n            \n              Financing Margin...       12%        9%
# 5              \n\n                Other Income +\n\n     7,987     8,303
# 6   \n            \n              Depreciation\n  ...         0         0
# 7   \n            \n              Profit before ta...    11,813    11,266
# 8   \n            \n              Tax %\n         ...       26%       25%
# 9                \n\n                Net Profit +\n\n     8,760     8,444
# 10  \n            \n              EPS in Rs\n     ...     15.92     15.30
# 11  \n            \n              Gross NPA %\n   ...
# ...

# %%
directory= 'C:\\Users\\User\OneDrive\\Documents\\screener_data\\'
# Create a new DataFrame to store all the data

for row in stock_list:
    b=os.path.join(directory, row)+".xlsx"
    
    for stock in stock_list:
        url = 'https://www.screener.in/company/'+stock
        table=pd.read_html(url,index_col=False)

        balance_sheet=table[6]
        profit_loss=table[1]
        cash_flow=table[7]
        time.sleep(5)
        with pd.ExcelWriter(b) as writer:
            balance_sheet.to_excel(writer,sheet_name="Balance_sheet")
            profit_loss.to_excel(writer,sheet_name="Profit_Loss_Statement")
            cash_flow.to_excel(writer,sheet_name="Cash_flow_Statement")
